# %%
# Verify Catalog and Schemas
display(spark.sql("SHOW SCHEMAS IN medical_catalog"))

# %%
# Verify Volume
display(spark.sql("SHOW VOLUMES IN medical_catalog.medical"))

# %%
# Verify CSV file is in Volume
files = dbutils.fs.ls("/Volumes/medical_catalog/medical/raw_files/")
for f in files:
    print(f.name, f.size)

# %%
# Quick preview of raw CSV
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("multiLine", "true") \
    .load("/Volumes/medical_catalog/medical/raw_files/medical_transcriptions.csv")

print("Rows:", df.count())
print("Columns:", df.columns)
display(df.limit(5))
